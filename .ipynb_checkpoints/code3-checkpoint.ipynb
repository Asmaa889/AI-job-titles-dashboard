# %% [markdown]
# # import libraries

# %%
import pandas as pd
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
import ast

# %% [markdown]
# # load files

# %%
df = pd.read_csv('Jobs-scrapping-and-Data-analysis-master/Preprocessed_data2.csv', na_values = 'Nan')
df
# Out:
#                             title       company  \
# 0                machine learning  Neural Magic
# 1                machine learning  Neural Magic
# 2                machine learning       Verneek
# 3                machine learning         Yakoa
# 4                machine learning  Chemix, Inc.
# ...                           ...           ...
# 8466  Natural Language Processing        Cresta
# 8467  Natural Language Processing        Cresta
# 8468  Natural Language Processing        Cresta
# 8469  Natural Language Processing        Cresta
# 8470  Natural Language Processing        Cresta
#
#                                             description onsite_remote salary  \
# 0     Neural Magic is an early-stage AI software com...        onsite    NaN
# 1     Neural Magic is an early-stage AI software com...        onsite    NaN
# 2     Do you want to be part of the core team for bu...        onsite    NaN
# 3     We’re looking for people who want to build for...        onsite    NaN
# 4     Chemix is seeking a highly-motivated graduate-...        onsite    NaN
# ...                                                 ...           ...    ...
# 8466                                                NaN        hybrid    NaN
# 8467                                                NaN        hybrid    NaN
# 8468                                                NaN        hybrid    NaN
# 8469                                                NaN        hybrid    NaN
# 8470                                                NaN        hybrid    NaN
#
#                       location  \
# 0               Somerville, MA
# 1               Somerville, MA
# 2      New York, United States
# 3            San Francisco, CA
# 4                Sunnyvale, CA
# ...                        ...
# 8466  Toronto, Ontario, Canada
# 8467  Toronto, Ontario, Canada
# 8468  Toronto, Ontario, Canada
# 8469  Toronto, Ontario, Canada
# 8470  Toronto, Ontario, Canada
#
#                                                criteria posted_date  \
# 0     [{'Seniority level': 'Associate'}, {'Employmen...  2023-02-19
# 1     [{'Seniority level': 'Mid-Senior level'}, {'Em...  2023-03-08
# 2     [{'Seniority level': 'Mid-Senior level'}, {'Em...  2023-02-27
# 3     [{'Seniority level': 'Mid-Senior level'}, {'Em...  2023-03-11
# 4     [{'Seniority level': 'Internship'}, {'Employme...  2023-03-09
# ...                                                 ...         ...
# 8466                                                 []  2023-03-23
# 8467                                                 []  2023-03-23
# 8468                                                 []  2023-03-23
# 8469                                                 []  2023-03-23
# 8470                                                 []  2023-03-23
#
#                                                    link country
# 0     https://www.linkedin.com/jobs/view/machine-lea...     usa
# 1     https://www.linkedin.com/jobs/view/machine-lea...     usa
# 2     https://www.linkedin.com/jobs/view/machine-lea...     usa
# 3     https://www.linkedin.com/jobs/view/machine-lea...     usa
# 4     https://www.linkedin.com/jobs/view/machine-lea...     usa
# ...                                                 ...     ...
# 8466  https://ca.linkedin.com/jobs/view/software-eng...  canada
# 8467  https://ca.linkedin.com/jobs/view/software-eng...  canada
# 8468  https://ca.linkedin.com/jobs/view/software-eng...  canada
# 8469  https://ca.linkedin.com/jobs/view/software-eng...  canada
# 8470  https://ca.linkedin.com/jobs/view/software-eng...  canada
#
# [8471 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8471 entries, 0 to 8470
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          8471 non-null   object
#  1   company        8471 non-null   object
#  2   description    6648 non-null   object
#  3   onsite_remote  8471 non-null   object
#  4   salary         356 non-null    object
#  5   location       8471 non-null   object
#  6   criteria       8471 non-null   object
#  7   posted_date    8471 non-null   object
#  8   link           8471 non-null   object
#  9   country        8471 non-null   object
# dtypes: object(10)
# memory usage: 661.9+ KB

# %% [markdown]
# # drop null columns

# %%
df.drop(columns = ['salary', 'link'], inplace = True)
df.fillna('N/A', inplace = True)

# %% [markdown]
# # preprocessing data

# %%
df['criteria'][13]
# Out:
# "[{'Seniority level': 'Mid-Senior level'}, {'Employment type': 'Full-time'}, {'Job function': 'Engineering and Information Technology'}, {'Industries': 'Internet Publishing'}]"

# %%
df['posted_date'] = pd.to_datetime(df['posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8471 entries, 0 to 8470
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          8471 non-null   object
#  1   company        8471 non-null   object
#  2   description    8471 non-null   object
#  3   onsite_remote  8471 non-null   object
#  4   location       8471 non-null   object
#  5   criteria       8471 non-null   object
#  6   posted_date    8471 non-null   datetime64[ns]
#  7   country        8471 non-null   object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 529.6+ KB

# %%
df['day'] = df['posted_date'].dt.day
df['month'] = df['posted_date'].dt.month
df['year'] = df['posted_date'].dt.year

# %%
df.drop(columns = ['posted_date'], inplace = True)

# %% [markdown]
# # split criteria column

# %%
df_cr = df['criteria']

# %%
# Convert the string to a list of dictionaries
list_of_dicts = df_cr.apply(lambda x: ast.literal_eval(x))

print(list_of_dicts)
# Out:
# 0       [{'Seniority level': 'Associate'}, {'Employmen...
# 1       [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 2       [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 3       [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 4       [{'Seniority level': 'Internship'}, {'Employme...
#                               ...
# 8466                                                   []
# 8467                                                   []
# 8468                                                   []
# 8469                                                   []
# 8470                                                   []
# Name: criteria, Length: 8471, dtype: object

# %%
list_of_dicts = list_of_dicts.apply(lambda x: x if (x!=[] and x != None) else [{'Seniority level': "N/A"},{'Employment type': "N/A"},{'Job function': "N/A"}, {'Industries': "N/A"}])

# %%
list_of_dicts[17: 20]
# Out:
# 17    [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 18    [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 19    [{'Seniority level': 'Internship'}, {'Employme...
# Name: criteria, dtype: object

# %%
dffff = pd.DataFrame.from_dict(list_of_dicts, orient= 'columns')

# %%
dffff
# Out:
#                                                criteria
# 0     [{'Seniority level': 'Entry level'}, {'Employm...
# 1     [{'Seniority level': 'Associate'}, {'Employmen...
# 2     [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 3     [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 4     [{'Seniority level': 'Entry level'}, {'Employm...
# ...                                                 ...
# 3560  [{'Seniority level': 'Entry level'}, {'Employm...
# 3561  [{'Seniority level': 'Entry level'}, {'Employm...
# 3562  [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 3563  [{'Seniority level': 'Mid-Senior level'}, {'Em...
# 3564  [{'Seniority level': 'Mid-Senior level'}, {'Em...
#
# [3565 rows x 1 columns]

# %%
old_key = 'مستوى الأقدمية'
new_key = 'Seniority level'
for d in dffff['criteria']:
    if any(old_key in i for i in d):
        a = [i for i, d in enumerate(d) if 'مستوى الأقدمية' in d.keys()]
        d[a[0]]['Seniority level'] = d[a[0]].pop('مستوى الأقدمية')
        print(d[a[0]])
        
#---------------------------------------------------

old_key = 'نوع التوظيف'
new_key = 'Employment type'
for d in dffff['criteria']:
    if any('نوع التوظيف' in x for x in d):
        a = [i for i, d in enumerate(d) if 'نوع التوظيف' in d.keys()]
        d[a[0]]['Employment type'] = d[a[0]].pop('نوع التوظيف')
        print(d[a[0]])
        
#---------------------------------------------------
        
old_key = 'المهام الوظيفية'
new_key = 'Job function'
for d in dffff['criteria']:
    if any(old_key in x for x in d):
        a = [i for i, d in enumerate(d) if old_key in d.keys()]
        d[a[0]]['Job function'] = d[a[0]].pop('المهام الوظيفية')
        print(d[a[0]])
        
#---------------------------------------------------
               
old_key = 'المجالات'
new_key = 'Industries'
for d in dffff['criteria']:
    if any('المجالات' in x for x in d):
        a = [i for i, d in enumerate(d) if old_key in d.keys()]
        d[a[0]]['Industries'] = d[a[0]].pop('المجالات')
        print(d[a[0]])
# Out:
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مساعد'}
# {'Seniority level': 'مستوى متوسط الأقدمية'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Seniority level': 'مستوى المبتدئين'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Employment type': 'دوام كامل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تأمين الجودة'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'تكنولوجيا المعلومات'}
# {'Job function': 'محلل'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Job function': 'الهندسة و تكنولوجيا المعلومات'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الخدمات والاستشارات في مجال تكنولوجيا المعلومات'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'النشر على الإنترنت'}
# {'Industries': 'الأعمال المصرفية'}
# {'Industries': 'التكنولوجيا والمعلومات والإنترنت'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}
# {'Industries': 'تطوير البرامج'}

# %%
dffff = pd.concat([dffff.drop('criteria', axis=1), dffff['criteria'].apply(lambda x: pd.Series({d: v for dic in x for d, v in dic.items()}))], axis=1)
dffff.head()
# Out:
#     Seniority level Employment type                            Job function  \
# 0       Entry level       Full-time  Engineering and Information Technology
# 1         Associate       Full-time  Engineering and Information Technology
# 2  Mid-Senior level       Full-time  Engineering and Information Technology
# 3  Mid-Senior level       Full-time  Engineering and Information Technology
# 4       Entry level       Full-time  Engineering and Information Technology
#
#                              Industries
# 0  Technology, Information and Internet
# 1                  Software Development
# 2  Technology, Information and Internet
# 3  Technology, Information and Internet
# 4  Technology, Information and Internet

# %%
dffff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3565 entries, 0 to 3564
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Seniority level  3468 non-null   object
#  1   Employment type  3565 non-null   object
#  2   Job function     3468 non-null   object
#  3   Industries       3467 non-null   object
# dtypes: object(4)
# memory usage: 111.5+ KB

# %%
dffff.fillna("N/A", inplace = True)

# %% [markdown]
# # modified data

# %%
df_copy = pd.concat((df, dffff), axis = 1)

# %%
df_copy.drop(columns = ['criteria'], inplace = True)
df_copy.head()
# Out:
#                                     title            company  \
# 0        Junior Machine Learning Engineer            Trulioo
# 1  Artificial intelligence (AI) Developer  ISAAC Instruments
# 2      Machine Learning Engineer (Canada)    Tiger Analytics
# 3      Machine Learning Engineer (Canada)    Tiger Analytics
# 4               Machine Learning Engineer              NTENT
#
#                                          description onsite_remote  \
# 0  At Trulioo, we build and connect digital ident...        onsite
# 1  Company DescriptionISAAC partners with North A...        onsite
# 2  Tiger Analytics is an advanced analytics consu...        onsite
# 3  Tiger Analytics is an advanced analytics consu...        onsite
# 4  Position: Full timeLocation: Toronto, Ontario ...        onsite
#
#                                   location country  day  month  year  \
# 0      Vancouver, British Columbia, Canada  canada   13      2  2023
# 1  St-Bruno-de-Montarville, Quebec, Canada  canada    4      4  2023
# 2                 Toronto, Ontario, Canada  canada   12      3  2023
# 3                 Toronto, Ontario, Canada  canada   12      3  2023
# 4                 Toronto, Ontario, Canada  canada    3      2  2023
#
#     Seniority level Employment type                            Job function  \
# 0       Entry level       Full-time  Engineering and Information Technology
# 1         Associate       Full-time  Engineering and Information Technology
# 2  Mid-Senior level       Full-time  Engineering and Information Technology
# 3  Mid-Senior level       Full-time  Engineering and Information Technology
# 4       Entry level       Full-time  Engineering and Information Technology
#
#                              Industries
# 0  Technology, Information and Internet
# 1                  Software Development
# 2  Technology, Information and Internet
# 3  Technology, Information and Internet
# 4  Technology, Information and Internet

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3565 entries, 0 to 3564
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3565 non-null   object
#  1   company          3565 non-null   object
#  2   description      3565 non-null   object
#  3   onsite_remote    3565 non-null   object
#  4   location         3565 non-null   object
#  5   country          3565 non-null   object
#  6   day              3565 non-null   int64
#  7   month            3565 non-null   int64
#  8   year             3565 non-null   int64
#  9   Seniority level  3565 non-null   object
#  10  Employment type  3565 non-null   object
#  11  Job function     3565 non-null   object
#  12  Industries       3565 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 362.2+ KB

# %%
np.where(df_copy['year'] == 2022)[0]
# Out:
# array([  12,   14,   21,   27,   62,   64,   70,   90,   98,  112,  114,
#         120,  137,  139,  145,  162,  164,  170,  186,  188,  195,  201,
#         236,  238,  244,  264,  272,  285,  287,  294,  311,  313,  319,
#         336,  338,  344,  361,  363,  369,  386,  388,  394,  411,  413,
#         419,  435,  437,  444,  461,  463,  469,  486,  488,  494,  509,
#         513,  534,  538,  560,  565,  585,  590,  610,  615,  635,  640,
#         659,  663,  684,  688,  710,  715,  735,  740,  759,  763,  785,
#         790,  810,  815,  835,  838,  860,  865,  885,  890,  910,  915,
#         935,  940,  960,  963, 1002, 1024, 1057, 1081, 1098, 1129, 1153,
#        1168, 1194, 1243, 1274, 1294, 1322, 1342, 1370, 1385, 1418, 1438,
#        1532, 1546, 1626, 1636, 1659, 1774, 1799, 2007, 2008, 2040, 2053,
#        2054, 2080, 2081, 2107, 2108, 2130, 2131, 2156, 2159, 2182, 2183,
#        2215, 2230, 2231, 2257, 2258, 2278, 2279, 2305, 2306, 2337, 2353,
#        2354, 2378, 2379, 2403, 2404, 2418, 2430, 2453, 2454, 2480, 2481,
#        2491, 2501, 2509, 2527, 2531, 2552, 2556, 2577, 2581, 2609, 2611,
#        2613, 2615, 2625, 2630, 2650, 2655, 2675, 2680, 2709, 2711, 2713,
#        2715, 2727, 2731, 2750, 2755, 2775, 2780, 2802, 2806, 2825, 2830,
#        2850, 2855, 2883, 2885, 2887, 2889, 2890, 2900, 2905, 2925, 2930,
#        2952, 2956, 2983, 2985, 2987, 2989, 2990, 3000, 3005, 3025, 3030,
#        3060, 3085, 3110, 3160, 3199, 3234, 3259, 3284, 3309, 3334, 3359,
#        3384, 3434, 3459, 3484, 3509, 3534, 3559], dtype=int64)

# %%
df['year'].value_counts()
# Out:
# 2023    3338
# 2022     227
# Name: year, dtype: int64

# %%
df_copy.drop(index = np.where(df_copy['year'] == 2022)[0], inplace = True)

# %%
df_copy['location'] = df_copy['location'].apply(lambda x: x.split(',')[0])

# %%
df_copy['location']
# Out:
# 0                     Vancouver
# 1       St-Bruno-de-Montarville
# 2                       Toronto
# 3                       Toronto
# 4                       Toronto
#                  ...
# 3560                   New York
# 3561                Albuquerque
# 3562                 Pittsburgh
# 3563                Bentonville
# 3564                Bentonville
# Name: location, Length: 3338, dtype: object

# %%
df_copy.drop(columns = ['year'], inplace = True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3338 entries, 0 to 3564
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3338 non-null   object
#  1   company          3338 non-null   object
#  2   description      3338 non-null   object
#  3   onsite_remote    3338 non-null   object
#  4   location         3338 non-null   object
#  5   country          3338 non-null   object
#  6   day              3338 non-null   int64
#  7   month            3338 non-null   int64
#  8   Seniority level  3338 non-null   object
#  9   Employment type  3338 non-null   object
#  10  Job function     3338 non-null   object
#  11  Industries       3338 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 339.0+ KB

# %% [markdown]
# # modify jobs title

# %%
lst = ['machine learning', 'ml']
df_copy['title'] = df_copy['title'].apply(lambda x: 'machine learning' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['computer vision', 'cv', 'computer_vision']
df_copy['title'] = df_copy['title'].apply(lambda x: 'Computer Vision' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['natural language processing', 'nlp']
df_copy['title'] = df_copy['title'].apply(lambda x: 'Natural Language Processing' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['data scientist', 'data_scientist', 'data science', 'scientifique', 'r&d scientist/engineer', 'data analyst/scientist', 'data analysis']
df_copy['title'] = df_copy['title'].apply(lambda x: 'Data Scientist' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['research']
df_copy['title'] = df_copy['title'].apply(lambda x: 'Researcher' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['artificial intelligence', 'ai']
df_copy['title'] = df_copy['title'].apply(lambda x: 'Artificial intelligence' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['game', 'gameplay']
df_copy['title'] = df_copy['title'].apply(lambda x: 'game programmer' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['software', 'front end engineer']
df_copy['title'] = df_copy['title'].apply(lambda x: 'software programmer' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['machine learning', 'Computer Vision', 'Natural Language Processing', 'Data Scientist', 'Researcher',
       'Artificial intelligence', 'game programmer', 'software programmer']
df_copy['title'] = df_copy['title'].apply(lambda x: 'other' if not any(pattern in x for pattern in lst) else x)

# %%
df_copy['title'].value_counts()
# Out:
# machine learning               1866
# Data Scientist                  728
# Artificial intelligence         433
# software programmer             109
# other                            75
# game programmer                  53
# Researcher                       50
# Natural Language Processing      24
# Name: title, dtype: int64

# %%
df_copy.head()
# Out:
#                      title            company  \
# 0         machine learning            Trulioo
# 1  Artificial intelligence  ISAAC Instruments
# 2         machine learning    Tiger Analytics
# 3         machine learning    Tiger Analytics
# 4         machine learning              NTENT
#
#                                          description onsite_remote  \
# 0  At Trulioo, we build and connect digital ident...        onsite
# 1  Company DescriptionISAAC partners with North A...        onsite
# 2  Tiger Analytics is an advanced analytics consu...        onsite
# 3  Tiger Analytics is an advanced analytics consu...        onsite
# 4  Position: Full timeLocation: Toronto, Ontario ...        onsite
#
#                   location country  day  month   Seniority level  \
# 0                Vancouver  canada   13      2       Entry level
# 1  St-Bruno-de-Montarville  canada    4      4         Associate
# 2                  Toronto  canada   12      3  Mid-Senior level
# 3                  Toronto  canada   12      3  Mid-Senior level
# 4                  Toronto  canada    3      2       Entry level
#
#   Employment type                            Job function  \
# 0       Full-time  Engineering and Information Technology
# 1       Full-time  Engineering and Information Technology
# 2       Full-time  Engineering and Information Technology
# 3       Full-time  Engineering and Information Technology
# 4       Full-time  Engineering and Information Technology
#
#                              Industries
# 0  Technology, Information and Internet
# 1                  Software Development
# 2  Technology, Information and Internet
# 3  Technology, Information and Internet
# 4  Technology, Information and Internet

# %% [markdown]
# ---

# %%
df_copy.onsite_remote.value_counts()
# Out:
# onsite    1383
# remote    1010
# hybrid     945
# Name: onsite_remote, dtype: int64

# %%
df_copy.country.value_counts()
# Out:
# usa       1464
# canada    1344
# africa     530
# Name: country, dtype: int64

# %%
df_copy.month.value_counts()
# Out:
# 3    1547
# 2     877
# 4     559
# 1     355
# Name: month, dtype: int64

# %% [markdown]
# # replace arabic values to english

# %%
df_copy['Seniority level'].value_counts()
# Out:
# Mid-Senior level        1284
# Entry level             1277
# Not Applicable           329
# N/A                      187
# Associate                146
# مستوى متوسط الأقدمية      47
# Internship                26
# مستوى المبتدئين           25
# مساعد                     16
# Director                   1
# Name: Seniority level, dtype: int64

# %%
rep = {'مستوى متوسط الأقدمية': 'Mid-Senior level', 'مستوى المبتدئين': 'Entry level', 'مساعد': 'Associate', 'N/A':'Not Applicable'}
df_copy['Seniority level'] = df_copy['Seniority level'].replace(rep)

# %%
df_copy['Seniority level'].value_counts()
# Out:
# Mid-Senior level    1331
# Entry level         1302
# Not Applicable       516
# Associate            162
# Internship            26
# Director               1
# Name: Seniority level, dtype: int64

# %%
df_copy['Employment type'].value_counts()
# Out:
# Full-time     2683
# Contract       401
# N/A             90
# دوام كامل       88
# Part-time       31
# Internship      24
# Other           17
# Temporary        4
# Name: Employment type, dtype: int64

# %%
rep = {'دوام كامل': 'Full-time', 'N/A':'Not Applicable'}
df_copy['Employment type'] = df_copy['Employment type'].replace(rep)

# %%
df_copy['Job function'].value_counts()
# Out:
# Engineering and Information Technology              2277
# Engineering                                          344
# N/A                                                  187
# Information Technology                               147
# Finance                                               96
# Information Technology and Engineering                66
# الهندسة و تكنولوجيا المعلومات                         58
# Strategy/Planning and Information Technology          20
# Design, Art/Creative, and Information Technology      20
# Quality Assurance                                     20
# Other                                                 19
# Engineering, Science, and Other                       18
# Project Management and Information Technology         18
# تكنولوجيا المعلومات                                   16
# محلل                                                  14
# Research, Analyst, and Information Technology         12
# Management and Manufacturing                           2
# Management, Other, and Engineering                     2
# Education and Training                                 1
# Sales and Business Development                         1
# Name: Job function, dtype: int64

# %%
rep = {'الهندسة و تكنولوجيا المعلومات': 'Information Technology and Engineering', 'تكنولوجيا المعلومات': 'Information Technology',
       'محلل': 'Research, Analyst, and Information Technology', 'N/A':'Not Applicable'}
df_copy['Job function'] = df_copy['Job function'].replace(rep)

# %%
pd.set_option('display.max_rows', 100)

# %%
df_copy['Industries'].value_counts()
# Out:
# Technology, Information and Internet                                                             919
# Software Development                                                                             521
# IT Services and IT Consulting                                                                    396
# Internet Publishing                                                                              192
# N/A                                                                                              188
# Staffing and Recruiting                                                                          182
# Transportation, Logistics, Supply Chain and Storage                                              131
# Defense and Space Manufacturing                                                                   58
# Nanotechnology Research                                                                           46
# Computer Games                                                                                    45
# Biotechnology Research                                                                            40
# Transportation, Logistics, Supply Chain and Storage and Internet Publishing                       40
# Online Audio and Video Media                                                                      37
# Information Technology & Services                                                                 35
# النشر على الإنترنت                                                                                32
# التكنولوجيا والمعلومات والإنترنت                                                                  32
# Financial Services                                                                                32
# Insurance                                                                                         26
# IT Services and IT Consulting, Software Development, and Technology, Information and Internet     21
# Venture Capital and Private Equity Principals                                                     20
# Human Resources                                                                                   18
# Transportation/Trucking/Railroad                                                                  18
# Plastics Manufacturing and Chemical Manufacturing                                                 18
# Machinery Manufacturing                                                                           18
# Computers and Electronics Manufacturing                                                           18
# IT Services and IT Consulting, Software Development, and Insurance                                17
# Government Administration                                                                         17
# Research Services                                                                                 17
# IT Services and IT Consulting and Business Consulting and Services                                17
# الأعمال المصرفية                                                                                  16
# Individual and Family Services                                                                    16
# Public Policy Offices                                                                             16
# IT Services and IT Consulting and Biotechnology Research                                          16
# Translation and Localization                                                                      12
# Banking                                                                                           11
# Investment Banking                                                                                 9
# تطوير البرامج                                                                                      7
# Software Development, Wireless Services, and Semiconductor Manufacturing                           7
# Technology, Information and Internet, Entertainment Providers, and Computer Games                  7
# Information Services and Software Development                                                      6
# Biotechnology                                                                                      5
# Public Safety                                                                                      4
# Banking, Insurance, and Financial Services                                                         4
# Computer Hardware Manufacturing                                                                    4
# Renewable Energy Equipment Manufacturing                                                           3
# Computer Networking Products                                                                       3
# IT Services and IT Consulting, Computer Hardware Manufacturing, and Software Development           3
# Construction and Machinery Manufacturing                                                           3
# Mining                                                                                             2
# Research Services and Oil and Gas                                                                  2
# Entertainment                                                                                      2
# Education Administration Programs                                                                  2
# Semiconductor Manufacturing                                                                        2
# Data Infrastructure and Analytics                                                                  2
# Hospitals and Health Care                                                                          2
# Human Resources Services                                                                           2
# Retail                                                                                             2
# Software Development, Technology, Information and Internet, and Financial Services                 2
# Automotive                                                                                         2
# Food and Beverage Services                                                                         2
# Professional Services                                                                              1
# Business Consulting and Services                                                                   1
# Mobile Gaming Apps                                                                                 1
# Public Health                                                                                      1
# Book and Periodical Publishing                                                                     1
# Advertising Services                                                                               1
# Motor Vehicle Manufacturing                                                                        1
# الخدمات والاستشارات في مجال تكنولوجيا المعلومات                                                    1
# Defense and Space Manufacturing and Aviation and Aerospace Component Manufacturing                 1
# Software Development, Insurance, and Financial Services                                            1
# Defense & Space                                                                                    1
# Name: Industries, dtype: int64

# %%
rep = {'الخدمات والاستشارات في مجال تكنولوجيا المعلومات': 'Information Technology & Services', 'النشر على الإنترنت': 'Internet Publishing',
       'التكنولوجيا والمعلومات والإنترنت': 'Information Technology and Engineering', 'الأعمال المصرفية': 'Banking', 
       'تطوير البرامج': 'Software Development, Wireless Services, and Semiconductor Manufacturing'}
df_copy['Industries'] = df_copy['Industries'].replace(rep)

# %%
lst = ['it services and it consulting']
df_copy['Industries'] = df_copy['Industries'].apply(lambda x: 'IT Services and IT Consulting' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['technology, information']
df_copy['Industries'] = df_copy['Industries'].apply(lambda x: 'Technology, Information and Internet' if any(pattern in x.lower() for pattern in lst) else x)

# %%
lst = ['transportation, logistics']
df_copy['Industries'] = df_copy['Industries'].apply(lambda x: 'Transportation, Logistics, Supply Chain and Storage' if any(pattern in x.lower() for pattern in lst) else x)

# %%
df['location'] = df['location'].replace({'6th of October':'Egypt','Qesm El Maadi':'Egypt', 'Cairo':'Egypt'})

# %%
df[df['location'] == 'Cairo']
# Out:
# Empty DataFrame
# Columns: [title, company, description, onsite_remote, location, criteria, country, day, month, year]
# Index: []

# %% [markdown]
# ### Word cloud

# %%
wordcloud = WordCloud(stopwords=set(STOPWORDS),width = 400, height = 400,
                background_color ='white',
                min_font_size = 10).generate(' '.join(df_copy.description.values[:]))
 
# plot the WordCloud image                      
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
# Get the list of all words from the text
words_list = []
for description in df_copy.description.values:
    words_list += description.lower().split()

# Count the frequency of each word
word_counts = Counter(words_list)

# Create WordCloud from the word frequency counts
wordcloud = WordCloud(stopwords=set(STOPWORDS),width = 400, height = 400,
                background_color ='white',
                min_font_size = 10).generate(' '.join(df_copy.description.values[:]))

# Plot the WordCloud image                      
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# Show the WordCloud and the word frequency counts
plt.show()
print(word_counts)
# Out:
# Counter({'and': 75156, 'to': 41118, 'the': 34088, 'of': 31309, 'in': 27193, 'a': 25640, 'with': 23868, 'for': 15934, 'data': 14307, 'our': 13761, 'or': 11584, 'we': 11060, 'learning': 10907, 'is': 10288, 'machine': 9560, 'on': 9001, 'as': 8944, 'are': 8787, 'you': 8605, 'experience': 8218, 'that': 7443, 'will': 7438, 'team': 6541, 'be': 6374, 'an': 6304, 'work': 5690, 'this': 5226, 'ai': 4721, 'from': 4476, 'at': 4403, 'have': 4305, 'by': 4277, 'working': 3559, 'computer': 3558, 'business': 3475, 'models': 3469, 'your': 3318, 'ml': 3220, 'such': 3171, 'their': 3157, 'software': 3113, 'all': 2971, 'development': 2772, 'deep': 2708, 'new': 2702, 'years': 2613, 'technical': 2555, 'engineering': 2550, 'using': 2456, 'help': 2453, '&': 2361, 'product': 2357, 'build': 2271, 'skills': 2271, 'including': 2196, 'about': 2188, 'science': 2174, 'solutions': 2168, 'other': 2143, 'knowledge': 2112, 'more': 2055, 'systems': 2034, '-': 2029, 'looking': 2012, 'strong': 1956, 'role': 1954, 'company': 1951, 'related': 1944, 'model': 1923, 'science,': 1895, 'like': 1893, 'research': 1883, 'engineer': 1877, 'can': 1848, 'develop': 1839, 'opportunity': 1834, 'building': 1831, 'degree': 1831, 'tools': 1825, 'algorithms': 1815, 'us': 1762, 'into': 1710, 'not': 1708, 'who': 1700, 'best': 1643, 'through': 1599, 'join': 1597, 'make': 1580, 'support': 1574, 'across': 1571, 'teams': 1561, 'production': 1542, 'if': 1512, 'based': 1512, 'design': 1506, 'communication': 1502, 'learning,': 1484, 'understanding': 1465, 'part': 1436, 'ability': 1388, 'members': 1385, 'people': 1379, 'it': 1367, 'one': 1352, 'technologies': 1349, 'also': 1345, 'python': 1324, 'use': 1301, 'language': 1298, 'every': 1293, 'grammarly': 1283, 'improve': 1281, 'highly': 1279, 'time': 1263, 'apply': 1259, 'any': 1244, 'provide': 1238, 'well': 1233, 'technology': 1228, 'code': 1220, 'programming': 1206, 'developing': 1204, 'create': 1201, 'cloud': 1196, 'large': 1194, 'do': 1192, 'may': 1190, 'information': 1182, 'complex': 1141, 'statistical': 1141, 'vision': 1136, 'analytics': 1135, 'mission': 1134, 'has': 1126, 'where': 1109, 'candidate': 1094, 'performance': 1093, 'implement': 1092, 'they': 1085, 'engineers': 1078, 'but': 1077, 'customer': 1063, 'most': 1046, 'please': 1045, 'which': 1033, 'environment': 1028, 'status,': 1026, 'analytical': 1019, 'job': 1013, 'frameworks': 1002, 'drive': 1001, 'paid': 988, 'platform': 986, 'problems': 982, 'advanced': 973, '–': 963, 'engineering,': 960, 'within': 947, 'collaborate': 941, 'both': 940, 'them': 930, 'quality': 923, 'health': 922, 'equal': 917, 'up': 915, 'management': 904, 'value': 901, 'diverse': 898, 'solve': 898, 'techniques': 894, 'its': 892, 'position': 889, 'analysis': 885, 'we’re': 879, 'industry': 869, 'various': 868, 'projects': 866, 'applications': 858, 'growth': 849, 'processing': 848, 'what': 845, 'intelligence': 832, 'services': 830, 'future': 828, 'benefits': 828, 'responsible': 824, 'employment': 819, 'python,': 819, 'opportunities': 818, 'compensation': 817, 'requirements': 815, 'professional': 814, 'per': 812, 'employees': 810, 'languages': 807, 'natural': 805, 'relevant': 805, 'career': 803, 'system': 802, 'identify': 800, 'range': 799, 'take': 798, 'statistics,': 794, 'collaboration': 791, 'impact': 791, 'candidates': 785, 'artificial': 781, 'ensure': 778, 'focus': 775, 'tech': 770, 'able': 770, 'understand': 769, 'over': 768, 'high': 767, 'clients': 763, 'closely': 759, 'key': 757, 'de': 754, 'process': 751, 'competitive': 745, 'innovative': 745, 'care': 745, 'tensorflow,': 743, 'libraries': 740, 'and/or': 739, 'growing': 733, 'learn': 724, 'scalable': 723, 'products': 722, 'insights': 719, 'customers': 717, 'salary': 716, 'infrastructure': 714, 'existing': 708, 'how': 702, 'digital': 699, 'implementing': 695, 'meet': 695, 'mathematics,': 694, 'team.': 692, 'project': 692, 'leading': 689, 'companies': 688, 'person': 688, 'want': 683, 'communicate': 680, 'skills,': 679, 'culture': 671, 'required': 669, 'offer': 66 ...

# %%
def word_cloud(text, num_words):
    # Convert text to lowercase
    text = text.str.lower()
    # Split text into words
    words = text.str.split()
    # Combine all lists of words into one list
    all_words = [word for word_list in words for word in word_list]
    # Remove stop words
    stopwords = set(STOPWORDS)
    all_words = [word for word in all_words if word not in stopwords]
    # Count the frequency of each word
    word_freq = Counter(all_words)
    # Get the most common words
    most_common = word_freq.most_common(num_words)
    # Create word cloud string
    word_cloud_str = ' '.join([word[0] + f' ({word[1]})' for word in most_common])
    # Return word cloud string
    return word_cloud_str

# %%
word_cloud_str = word_cloud(df_copy['description'], 10)
print(word_cloud_str)  # Output: "sample text data analysis"
# Out:
# data (14307) learning (10907) machine (9560) experience (8218) will (7438) team (6541) work (5690) ai (4721) working (3559) computer (3558)

# %%
df_copy.to_csv("Preprocessed_data.csv", index= False)

# %%
dff = pd.read_csv("Preprocessed_data.csv")
dff
# Out:
#                         title                    company  \
# 0            machine learning                    Trulioo
# 1     Artificial intelligence          ISAAC Instruments
# 2            machine learning            Tiger Analytics
# 3            machine learning            Tiger Analytics
# 4            machine learning                      NTENT
# ...                       ...                        ...
# 3333         machine learning                  Hebbia AI
# 3334         machine learning              SynergisticIT
# 3335  Artificial intelligence                   preamble
# 3336         machine learning                Saransh Inc
# 3337           Data Scientist  Global Soft Systems, Inc.
#
#                                             description onsite_remote  \
# 0     At Trulioo, we build and connect digital ident...        onsite
# 1     Company DescriptionISAAC partners with North A...        onsite
# 2     Tiger Analytics is an advanced analytics consu...        onsite
# 3     Tiger Analytics is an advanced analytics consu...        onsite
# 4     Position: Full timeLocation: Toronto, Ontario ...        onsite
# ...                                                 ...           ...
# 3333  About HebbiaHebbia is reinventing the search e...        hybrid
# 3334  Synergistic IT is a full-service staffing and ...        hybrid
# 3335  Our mission is to ensure AI systems have equal...        hybrid
# 3336  Notes :: The ideal candidate should have exper...        hybrid
# 3337  Role: Data Scientist Preferred Dallas or Bento...        hybrid
#
#                      location country  day  month   Seniority level  \
# 0                   Vancouver  canada   13      2       Entry level
# 1     St-Bruno-de-Montarville  canada    4      4         Associate
# 2                     Toronto  canada   12      3  Mid-Senior level
# 3                     Toronto  canada   12      3  Mid-Senior level
# 4                     Toronto  canada    3      2       Entry level
# ...                       ...     ...  ...    ...               ...
# 3333                 New York     usa    5      2       Entry level
# 3334              Albuquerque     usa   16      2       Entry level
# 3335               Pittsburgh     usa    1      4  Mid-Senior level
# 3336              Bentonville     usa    9      3  Mid-Senior level
# 3337              Bentonville     usa    9      2  Mid-Senior level
#
#      Employment type                            Job function  \
# 0          Full-time  Engineering and Information Technology
# 1          Full-time  Engineering and Information Technology
# 2          Full-time  Engineering and Information Technology
# 3          Full-time  Engineering and Information Technology
# 4          Full-time  Engineering and Information Technology
# ...              ...                                     ...
# 3333       Full-time  Engineering and Information Technology
# 3334        Contract  Engineering and Information Technology
# 3335       Part-time  Engineering and Information Technology
# 3336        Contract  Engineering and Information Technology
# 3337       Full-time  Engineering and Information Technology
#
#                                 Industries
# 0     Technology, Information and Internet
# 1                     Software Development
# 2     Technology, Information and Internet
# 3     Technology, Information and Internet
# 4     Technology, Information and Internet
# ...                                    ...
# 3333                  Software Development
# 3334         IT Services and IT Consulting
# 3335                  Software Development
# 3336         IT Services and IT Consulting
# 3337     Information Technology & Services
#
# [3338 rows x 12 columns]

# %%
dff['title'].value_counts()
# Out:
# machine learning               1866
# Data Scientist                  728
# Artificial intelligence         433
# software programmer             109
# other                            75
# game programmer                  53
# Researcher                       50
# Natural Language Processing      24
# Name: title, dtype: int64

# %% [markdown]
# # get highest 5 values to each job in each country

# %%
df_ml_c = dff[(dff['title'] == 'machine learning') & (dff['country'] == 'canada')]
gb2 = df_ml_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'


df_ml_u = dff[(dff['title'] == 'machine learning') & (dff['country'] == 'usa')]
gb3 = df_ml_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_ml_a = dff[(dff['title'] == 'machine learning') & (dff['country'] == 'africa')]
gb4 = df_ml_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'
gb4[:5]
# Out:
#                           company  title  description  onsite_remote  \
# 15                         Turing     17           17             17
# 12              The Boothby Group     18           16             18
# 1   Bluferry Consulting (Pty) Ltd     15           15             15
# 11                      SSC Egypt     15           15             15
# 4                     Flash Group     14           14             14
#
#     location country  day  month  Seniority level  Employment type  \
# 15        17  africa   17     17               17               17
# 12        18  africa   18     18               18               18
# 1         15  africa   15     15               15               15
# 11        15  africa   15     15               15               15
# 4         14  africa   14     14               14               14
#
#     Job function  Industries
# 15            17          17
# 12            18          16
# 1             15          15
# 11            15          15
# 4             14          14

# %%
df_ml = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_ml['title'] = 'machine learning'
df_ml
# Out:
#                           company             title  description  \
# 12                      Grammarly  machine learning          100
# 42                         owl.co  machine learning           57
# 37                Tiger Analytics  machine learning           57
# 15                         Hopper  machine learning           20
# 6                         Dropbox  machine learning           20
# 69                  SynergisticIT  machine learning           75
# 42                Lockheed Martin  machine learning           50
# 13                    Constructor  machine learning           41
# 62                     Sapling.ai  machine learning           40
# 49                   Neural Magic  machine learning           36
# 15                         Turing  machine learning           17
# 12              The Boothby Group  machine learning           16
# 1   Bluferry Consulting (Pty) Ltd  machine learning           15
# 11                      SSC Egypt  machine learning           15
# 4                     Flash Group  machine learning           14
#
#     onsite_remote  location country  day  month  Seniority level  \
# 12            109       109  canada  109    109              109
# 42             58        58  canada   58     58               58
# 37             58        58  canada   58     58               58
# 15             20        20  canada   20     20               20
# 6              25        25  canada   25     25               25
# 69             75        75     usa   75     75               75
# 42             50        50     usa   50     50               50
# 13             42        42     usa   42     42               42
# 62             40        40     usa   40     40               40
# 49             36        36     usa   36     36               36
# 15             17        17  africa   17     17               17
# 12             18        18  africa   18     18               18
# 1              15        15  africa   15     15               15
# 11             15        15  africa   15     15               15
# 4              14        14  africa   14     14               14
#
#     Employment type  Job function  Industries
# 12              109           109         100
# 42               58            58          57
# 37               58            58          57
# 15               20            20          20
# 6                25            25          20
# 69               75            75          75
# 42               50            50          50
# 13               42            42          41
# 62               40            40          40
# 49               36            36          36
# 15               17            17          17
# 12               18            18          16
# 1                15            15          15
# 11               15            15          15
# 4                14            14          14

# %%
df_ds_c = dff[(dff['title'] == 'Data Scientist') & (dff['country'] == 'canada')]
gb2 = df_ds_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_ds_u = dff[(dff['title'] == 'Data Scientist') & (dff['country'] == 'usa')]
gb3 = df_ds_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_ds_a = dff[(dff['title'] == 'Data Scientist') & (dff['country'] == 'africa')]
gb4 = df_ds_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

gb4[:5]
# Out:
#                    company  title  description  onsite_remote  location  \
# 17         RPO Recruitment     74           67             74        74
# 11        Hire Resolve .US     30           29             30        30
# 5       Cobblestone Energy     30           27             30        30
# 20  Société Générale Maroc     16           16             16        16
# 0                 Acredius     15           15             15        15
#
#    country  day  month  Seniority level  Employment type  Job function  \
# 17  africa   74     74               74               74            74
# 11  africa   30     30               30               30            30
# 5   africa   30     30               30               30            30
# 20  africa   16     16               16               16            16
# 0   africa   15     15               15               15            15
#
#     Industries
# 17          67
# 11          29
# 5           27
# 20          16
# 0           15

# %%
df_ds = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_ds['title'] = 'Data Scientist'
df_ds
# Out:
#                       company           title  description  onsite_remote  \
# 16      Zany Consulting Group  Data Scientist           20             20
# 6                FPT Software  Data Scientist           19             20
# 12                  Outdefine  Data Scientist           19             19
# 13          Rakuten Kobo Inc.  Data Scientist           18             18
# 9           ISAAC Instruments  Data Scientist           18             18
# 24              SynergisticIT  Data Scientist           20             20
# 8   Global Soft Systems, Inc.  Data Scientist           18             18
# 20               Revelio Labs  Data Scientist           17             17
# 19    Optimal Solutions Group  Data Scientist           17             17
# 18                     Ollang  Data Scientist           17             17
# 17            RPO Recruitment  Data Scientist           67             74
# 11           Hire Resolve .US  Data Scientist           29             30
# 5          Cobblestone Energy  Data Scientist           27             30
# 20     Société Générale Maroc  Data Scientist           16             16
# 0                    Acredius  Data Scientist           15             15
#
#     location country  day  month  Seniority level  Employment type  \
# 16        20  canada   20     20               20               20
# 6         20  canada   20     20               20               20
# 12        19  canada   19     19               19               19
# 13        18  canada   18     18               18               18
# 9         18  canada   18     18               18               18
# 24        20     usa   20     20               20               20
# 8         18     usa   18     18               18               18
# 20        17     usa   17     17               17               17
# 19        17     usa   17     17               17               17
# 18        17     usa   17     17               17               17
# 17        74  africa   74     74               74               74
# 11        30  africa   30     30               30               30
# 5         30  africa   30     30               30               30
# 20        16  africa   16     16               16               16
# 0         15  africa   15     15               15               15
#
#     Job function  Industries
# 16            20          20
# 6             20          19
# 12            19          19
# 13            18          18
# 9             18          18
# 24            20          20
# 8             18          18
# 20            17          17
# 19            17          16
# 18            17          17
# 17            74          67
# 11            30          29
# 5             30          27
# 20            16          16
# 0             15          15

# %%
df_ai_c = dff[(dff['title'] == 'Artificial intelligence') & (dff['country'] == 'canada')]
gb2 = df_ai_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_ai_u = dff[(dff['title'] == 'Artificial intelligence') & (dff['country'] == 'usa')]
gb3 = df_ai_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_ai_a = dff[(dff['title'] == 'Artificial intelligence') & (dff['country'] == 'africa')]
gb4 = df_ai_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

df_ai = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_ai['title'] = 'Artificial intelligence'
df_ai
# Out:
#                           company                    title  description  \
# 2   Fingerprint for Success (F4S)  Artificial intelligence           20
# 4               ISAAC Instruments  Artificial intelligence           20
# 9                   NetEase Games  Artificial intelligence           20
# 5                           Levio  Artificial intelligence           18
# 12                   Timbre Games  Artificial intelligence           18
# 21                       preamble  Artificial intelligence           20
# 16   Stillwater Human Capital LLC  Artificial intelligence           20
# 5                       Distyl AI  Artificial intelligence           19
# 19                          Vorto  Artificial intelligence           18
# 6                    Diverse Lynx  Artificial intelligence           18
# 2                    PaxeraHealth  Artificial intelligence           17
# 0   Bluferry Consulting (Pty) Ltd  Artificial intelligence           16
# 1     Inbound Technology Co. Ltd.  Artificial intelligence           14
# 3                          Turing  Artificial intelligence           13
#
#     onsite_remote  location country  day  month  Seniority level  \
# 2              20        20  canada   20     20               20
# 4              20        20  canada   20     20               20
# 9              20        20  canada   20     20               20
# 5              18        18  canada   18     18               18
# 12             18        18  canada   18     18               18
# 21             20        20     usa   20     20               20
# 16             20        20     usa   20     20               20
# 5              19        19     usa   19     19               19
# 19             18        18     usa   18     18               18
# 6              18        18     usa   18     18               18
# 2              17        17  africa   17     17               17
# 0              17        17  africa   17     17               17
# 1              14        14  africa   14     14               14
# 3              13        13  africa   13     13               13
#
#     Employment type  Job function  Industries
# 2                20            20          20
# 4                20            20          20
# 9                20            20          20
# 5                18            18          18
# 12               18            18          18
# 21               20            20          20
# 16               20            20          20
# 5                19            19          19
# 19               18            18          18
# 6                18            18          18
# 2                17            17          17
# 0                17            17          16
# 1                14            14          14
# 3                13            13          13

# %%
df_sp_c = dff[(dff['title'] == 'software programmer') & (dff['country'] == 'canada')]
gb2 = df_sp_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_sp_u = dff[(dff['title'] == 'software programmer') & (dff['country'] == 'usa')]
gb3 = df_sp_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_sp_a = dff[(dff['title'] == 'software programmer') & (dff['country'] == 'africa')]
gb4 = df_sp_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

df_sp = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_sp['title'] = 'software programmer'
df_sp
# Out:
#       company                title  description  onsite_remote  location  \
# 1  AssemblyAI  software programmer           34             36        36
# 7     bodo.ai  software programmer           19             19        19
# 2      Cresta  software programmer           18             18        18
# 6     ZestyAI  software programmer           11             12        12
# 0    Agnostiq  software programmer           10             12        12
# 0   Capgemini  software programmer            1              1         1
#
#   country  day  month  Seniority level  Employment type  Job function  \
# 1  canada   36     36               36               36            36
# 7  canada   19     19               19               19            19
# 2  canada   18     18               18               18            18
# 6  canada   12     12               12               12            12
# 0  canada   12     12               12               12            12
# 0  africa    1      1                1                1             1
#
#    Industries
# 1          34
# 7          19
# 2          18
# 6          11
# 0          10
# 0           1

# %%
df_gp_c = dff[(dff['title'] == 'game programmer') & (dff['country'] == 'canada')]
gb2 = df_gp_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_gp_u = dff[(dff['title'] == 'game programmer') & (dff['country'] == 'usa')]
gb3 = df_gp_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_gp_a = dff[(dff['title'] == 'game programmer') & (dff['country'] == 'africa')]
gb4 = df_gp_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

df_gp = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_gp['title'] = 'game programmer'
df_gp
# Out:
#                      company            title  description  onsite_remote  \
# 2   Brass Lion Entertainment  game programmer            8              8
# 13                 White Bay  game programmer            7              7
# 4           DoubleJump Games  game programmer            6              7
# 10             QUANTIC DREAM  game programmer            6              7
# 11        Ubisoft Sherbrooke  game programmer            6              7
#
#     location country  day  month  Seniority level  Employment type  \
# 2          8  canada    8      8                8                8
# 13         7  canada    7      7                7                7
# 4          7  canada    7      7                7                7
# 10         7  canada    7      7                7                7
# 11         7  canada    7      7                7                7
#
#     Job function  Industries
# 2              8           8
# 13             7           7
# 4              7           6
# 10             7           6
# 11             7           6

# %%
df_rs_c = dff[(dff['title'] == 'Researcher') & (dff['country'] == 'canada')]
gb2 = df_rs_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_rs_u = dff[(dff['title'] == 'Researcher') & (dff['country'] == 'usa')]
gb3 = df_rs_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_rs_a = dff[(dff['title'] == 'Researcher') & (dff['country'] == 'africa')]
gb4 = df_rs_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

df_rs = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_rs['title'] = 'Researcher'
df_rs
# Out:
#              company       title  description  onsite_remote  location  \
# 0  Valence Discovery  Researcher           16             16        16
# 0    Neo Cybernetica  Researcher           34             34        34
#
#   country  day  month  Seniority level  Employment type  Job function  \
# 0  canada   16     16               16               16            16
# 0     usa   34     34               34               34            34
#
#    Industries
# 0          16
# 0          34

# %%
df_nlp_c = dff[(dff['title'] == 'Natural Language Processing') & (dff['country'] == 'canada')]
gb2 = df_nlp_c.groupby(['company']).count()
gb2 = gb2.reset_index()
gb2 = gb2.sort_values(by= ['description'], ascending= False)
gb2['country'] = 'canada'

df_nlp_u = dff[(dff['title'] == 'Natural Language Processing') & (dff['country'] == 'usa')]
gb3 = df_nlp_u.groupby(['company']).count()
gb3 = gb3.reset_index()
gb3 = gb3.sort_values(by= ['description'], ascending= False)
gb3['country'] = 'usa'

df_nlp_a = dff[(dff['title'] == 'Natural Language Processing') & (dff['country'] == 'africa')]
gb4 = df_nlp_a.groupby(['company']).count()
gb4 = gb4.reset_index()
gb4 = gb4.sort_values(by= ['description'], ascending= False)
gb4['country'] = 'africa'

df_nlp = pd.concat((gb2[:5], gb3[:5], gb4[:5]), axis = 0)
df_nlp['title'] = 'Natural Language Processing'
df_nlp
# Out:
#                    company                        title  description  \
# 0  Experience AI Solutions  Natural Language Processing           19
# 0                 Saviance  Natural Language Processing            5
#
#    onsite_remote  location country  day  month  Seniority level  \
# 0             19        19  canada   19     19               19
# 0              5         5     usa    5      5                5
#
#    Employment type  Job function  Industries
# 0               19            19          19
# 0                5             5           5

# %%
dfall = pd.concat((df_ml, df_ds, df_ai, df_sp, df_gp, df_rs, df_nlp), axis = 0)
dfall.to_csv("highest companies.csv", index= False)

# %%
dfall
# Out:
#                           company                        title  description  \
# 12                      Grammarly             machine learning          100
# 42                         owl.co             machine learning           57
# 37                Tiger Analytics             machine learning           57
# 15                         Hopper             machine learning           20
# 6                         Dropbox             machine learning           20
# 69                  SynergisticIT             machine learning           75
# 42                Lockheed Martin             machine learning           50
# 13                    Constructor             machine learning           41
# 62                     Sapling.ai             machine learning           40
# 49                   Neural Magic             machine learning           36
# 15                         Turing             machine learning           17
# 12              The Boothby Group             machine learning           16
# 1   Bluferry Consulting (Pty) Ltd             machine learning           15
# 11                      SSC Egypt             machine learning           15
# 4                     Flash Group             machine learning           14
# 16          Zany Consulting Group               Data Scientist           20
# 6                    FPT Software               Data Scientist           19
# 12                      Outdefine               Data Scientist           19
# 13              Rakuten Kobo Inc.               Data Scientist           18
# 9               ISAAC Instruments               Data Scientist           18
# 24                  SynergisticIT               Data Scientist           20
# 8       Global Soft Systems, Inc.               Data Scientist           18
# 20                   Revelio Labs               Data Scientist           17
# 19        Optimal Solutions Group               Data Scientist           17
# 18                         Ollang               Data Scientist           17
# 17                RPO Recruitment               Data Scientist           67
# 11               Hire Resolve .US               Data Scientist           29
# 5              Cobblestone Energy               Data Scientist           27
# 20         Société Générale Maroc               Data Scientist           16
# 0                        Acredius               Data Scientist           15
# 2   Fingerprint for Success (F4S)      Artificial intelligence           20
# 4               ISAAC Instruments      Artificial intelligence           20
# 9                   NetEase Games      Artificial intelligence           20
# 5                           Levio      Artificial intelligence           18
# 12                   Timbre Games      Artificial intelligence           18
# 21                       preamble      Artificial intelligence           20
# 16   Stillwater Human Capital LLC      Artificial intelligence           20
# 5                       Distyl AI      Artificial intelligence           19
# 19                          Vorto      Artificial intelligence           18
# 6                    Diverse Lynx      Artificial intelligence           18
# 2                    PaxeraHealth      Artificial intelligence           17
# 0   Bluferry Consulting (Pty) Ltd      Artificial intelligence           16
# 1     Inbound Technology Co. Ltd.      Artificial intelligence           14
# 3                          Turing      Artificial intelligence           13
# 1                      AssemblyAI          software programmer           34
# 7                         bodo.ai          software programmer           19
# 2                          Cresta          software programmer           18
# 6                         ZestyAI          software programmer           11
# 0                        Agnostiq          software programmer           10
# 0                       Capgemini          software programmer            1
# 2        Brass Lion Entertainment              game programmer            8
# 13                      White Bay              game programmer            7
# 4                DoubleJump Games              game programmer            6
# 10                  QUANTIC DREAM              game programmer            6
# 11             Ubisoft Sherbrooke              game programmer            6
# 0               Valence Discovery                   Researcher           16
# 0                 Neo Cybernetica                   Researcher           34
# 0         Experience AI Solutions  Natural Language Processing           19
# 0                        Saviance  Natural Language Processing            5
#
#     onsite_remote  location country  day  month  Seniority level  \
# 12            109       109  canada  109    109              109
# 42             58        58  canada   58     58               58
# 37             58        58  canada   58     58               58
# 15             20        20  canada   20     20               20
# 6              25        25  canada   25     25               25
# 69             75        75     usa   75     75               75
# 42             50        50     usa   50     50               50
# 13             42        42     usa   42     42               42
# 62             40        40     usa   40     40               40
# 49             36        36     usa   36     36               36
# 15             17        17  africa   17     17               17
# 12             18        18  africa   18     18               18
# 1              15        15  africa   15     15               15
# 11             15        15  africa   15     15               15
# 4              14        14  africa   14     14               14
# 16             20        20  canada   20     20               20
# 6              20        20  canada   20     20               20
# 12             19        19  canada   19     19               19
# 13             18        18  canada   18     18               18
# 9              18        18  canada   18     18               18
# 24             20        20     usa   20     20               20
# 8              18        18     usa   18     18               18
# 20             17        17     usa   17     17               17
# 19             17        17     usa   17     17               17
# 18             17        17     usa   17     17               17
# 17             74        74  africa   74     74               74
# 11             30        30  africa   30     30               30
# 5              30        30  africa   30     30               30
# 20             16        16  africa   16     16               16
# 0              15        15  africa   15     15               15
# 2              20        20  canada   20     20               20
# 4              20        20  canada   20     20               20
# 9              20        20  canada   20     20               20
# 5              18        18  canada   18     18               18
# 12             18        18  canada   18     18               18
# 21             20        20     usa   20     20               20
# 16             20        20     usa   20     20               20
# 5              19        19     usa   19     19               19
# 19             18        18     usa   18     18               18
# 6              18        18     usa   18     18               18
# 2              17        17  africa   17     17               17
# 0              17        17  africa   17     17               17
# 1              14        14  africa   14     14               14
# 3              13        13  africa   13     13               13
# 1              36        36  canada   36     36               36
# 7              19        19  canada   19     19               19
# 2              18        18  canada   18     18               18
# 6              12        12  canada   12     12               12
# 0              12        12  canada   12     12               12
# 0               1         1  africa    1      1                1
# 2               8         8  canada    8      8                8
# 13              7         7  canada    7      7                7
# 4               7         7  canada    7      7                7
# 10              7         7  canada    7      7                7
# 11              7         7  canada    7      7                7
# 0              16        16  canada   16     16               16
# 0              34        34     usa   34     34               34
# 0              19        19  canada   19     19               19
# 0               5         5     usa    5      5                5
#
#     Employment type  Job function  Industries
# 12              109           109         100
# 42               58            58          57
# 37               58            58          57
# 15               20            20          20
# 6                25            25          20
# 69               75            75          75
# 42               50            50          50
# 13               42            42          41
# 62               40            40          40
# 49               36            36          36
# 15               17            17          17
# 12               18            18          16
# 1                15            15          15
# 11               15            15          15
# 4                14            14          14
# 16               20            20          20
# 6                20            20          19
# 12               19            19          19
# 13               18            18          18
# 9                18            18          18
# 24               20            20          20
# 8                18            18          18
# 20               17            17          17
# 19               17            17          16
# 18               17            17          17
# 17               74            74          67
# 11               30            30          29
# 5                30            30          27
# 20               16            16          16
# 0                15            15          15
# 2                20            20          20
# 4                20            20          20
# 9                20            20          20
# 5                18            18          18
# 12               18            18          18
# 21               20            20          20
# 16               20            20          20
# 5                19            19          19
# 19               18            18          18
# 6                18            18          18
# 2                17            17          17
# 0                17            17          16
# 1                14            14          14
# 3                13            13          13
# 1                36            36          34
# 7                19            19          19
# 2                18            18          18
# 6                12            12          11
# 0                12            12          10
# 0                 1             1           1
# 2                 8             8           8
# 13                7             7           7
# 4                 7             7           6
# 10                7             7           6
# 11                7             7           6
# 0                16            16          16
# 0                34            34          34
# 0                19            19          19
# 0                 5             5           5
